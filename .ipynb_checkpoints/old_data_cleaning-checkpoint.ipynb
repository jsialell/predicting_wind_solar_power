# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Read power generation data
production = pd.read_csv("./data/time_series_60min_singleindex_filtered_2014-2016.csv",
                        parse_dates=[0], index_col=0)
production.head()
# Out:
#                                  cet_cest_timestamp  \
# utc_timestamp
# 2013-12-31 23:00:00+00:00  2014-01-01T00:00:00+0100
# 2014-01-01 00:00:00+00:00  2014-01-01T01:00:00+0100
# 2014-01-01 01:00:00+00:00  2014-01-01T02:00:00+0100
# 2014-01-01 02:00:00+00:00  2014-01-01T03:00:00+0100
# 2014-01-01 03:00:00+00:00  2014-01-01T04:00:00+0100
#
#                            DE_load_actual_entsoe_power_statistics  \
# utc_timestamp
# 2013-12-31 23:00:00+00:00                            46892.783505
# 2014-01-01 00:00:00+00:00                            44936.082474
# 2014-01-01 01:00:00+00:00                            43104.123711
# 2014-01-01 02:00:00+00:00                            42017.525773
# 2014-01-01 03:00:00+00:00                            41224.742268
#
#                            DE_price_day_ahead  DE_solar_capacity  \
# utc_timestamp
# 2013-12-31 23:00:00+00:00               15.15              36012
# 2014-01-01 00:00:00+00:00               12.96              36012
# 2014-01-01 01:00:00+00:00               12.09              36012
# 2014-01-01 02:00:00+00:00               11.70              36012
# 2014-01-01 03:00:00+00:00               11.66              36012
#
#                            DE_solar_generation_actual  DE_wind_capacity  \
# utc_timestamp
# 2013-12-31 23:00:00+00:00                         0.0             32425
# 2014-01-01 00:00:00+00:00                         0.0             32425
# 2014-01-01 01:00:00+00:00                         0.0             32425
# 2014-01-01 02:00:00+00:00                         0.0             32425
# 2014-01-01 03:00:00+00:00                         0.0             32425
#
#                            DE_wind_generation_actual
# utc_timestamp
# 2013-12-31 23:00:00+00:00                     8504.0
# 2014-01-01 00:00:00+00:00                     8086.0
# 2014-01-01 01:00:00+00:00                     8803.0
# 2014-01-01 02:00:00+00:00                     8970.0
# 2014-01-01 03:00:00+00:00                     8510.0

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26328 entries, 2013-12-31 23:00:00+00:00 to 2017-01-01 22:00:00+00:00
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   cet_cest_timestamp                      26328 non-null  object
#  1   DE_load_actual_entsoe_power_statistics  26328 non-null  float64
#  2   DE_price_day_ahead                      26325 non-null  float64
#  3   DE_solar_capacity                       26328 non-null  int64
#  4   DE_solar_generation_actual              26305 non-null  float64
#  5   DE_wind_capacity                        26328 non-null  int64
#  6   DE_wind_generation_actual               26324 non-null  float64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.6+ MB

# %%
production.isna().sum()
# Out:
# cet_cest_timestamp                         0
# DE_load_actual_entsoe_power_statistics     0
# DE_price_day_ahead                         3
# DE_solar_capacity                          0
# DE_solar_generation_actual                23
# DE_wind_capacity                           0
# DE_wind_generation_actual                  4
# dtype: int64

# %%
# just keep the columns relevant for the project, i.e. the total power generation and capacity
columns = ["DE_solar_capacity", 
           "DE_solar_generation_actual", 
           "DE_wind_capacity",
           "DE_wind_generation_actual"]

production = production[[col for col in columns]]
production = production.rename(columns={"DE_solar_capacity": "solar_capacity",
                                        "DE_solar_generation_actual": "solar_generation_actual",
                                        "DE_wind_capacity": "wind_capacity",
                                        "DE_wind_generation_actual": "wind_generation_actual"})
production.head()
# Out:
#                            solar_capacity  solar_generation_actual  \
# utc_timestamp
# 2013-12-31 23:00:00+00:00           36012                      0.0
# 2014-01-01 00:00:00+00:00           36012                      0.0
# 2014-01-01 01:00:00+00:00           36012                      0.0
# 2014-01-01 02:00:00+00:00           36012                      0.0
# 2014-01-01 03:00:00+00:00           36012                      0.0
#
#                            wind_capacity  wind_generation_actual
# utc_timestamp
# 2013-12-31 23:00:00+00:00          32425                  8504.0
# 2014-01-01 00:00:00+00:00          32425                  8086.0
# 2014-01-01 01:00:00+00:00          32425                  8803.0
# 2014-01-01 02:00:00+00:00          32425                  8970.0
# 2014-01-01 03:00:00+00:00          32425                  8510.0

# %%
# When plotting solar and wind power generation over time (i.e. index), the following error kept on popping up:
# plot float() argument must be a string or a number, not 'Timestamp'
# It appears that the matplotlib converters were deregistered.
# The following code circumvents this issue:
pd.plotting.register_matplotlib_converters()

# %%
# Exploratory Data Analysis: create plot for wind power generation
fig, ax = plt.subplots(figsize=(8,5))

ax.plot(production.index,
        production['wind_generation_actual'],
        color="b");
ax.set_title("Wind generation in Germany in MW");
ax.set_xlim((pd.to_datetime("2014-01-01"), pd.to_datetime("2017-01-01")));
ax.set_ylim((0,38000));
ax.set_frame_on(False);

# save plot
# plt.savefig("figs/wind.png", dpi=200)

# %%
# Exploratory Data Analysis: create plot for solar power generation
fig, ax = plt.subplots(figsize=(8,5))

ax.plot(production.index,
        production['solar_generation_actual'],
        color="OrangeRed");
ax.set_title("Solar generation in Germany in MW");
ax.set_xlim((pd.to_datetime("2014-01-01"), pd.to_datetime("2017-01-01")));
ax.set_ylim((0,27000));
ax.set_frame_on(False);

# save plot
# plt.savefig("figs/solar.png", dpi=200)

# %%
# Read weather data
weather = pd.read_csv("./data/weather_data_filtered_2014-2016.csv",
                     parse_dates=[0], index_col=0)
weather.head()
# Out:
#                            DE_windspeed_10m  DE_temperature  \
# utc_timestamp
# 2014-01-01 00:00:00+00:00          4.981596          -0.568
# 2014-01-01 01:00:00+00:00          4.932105          -0.509
# 2014-01-01 02:00:00+00:00          4.865019          -0.436
# 2014-01-01 03:00:00+00:00          4.842338          -0.257
# 2014-01-01 04:00:00+00:00          4.772505          -0.082
#
#                            DE_radiation_direct_horizontal  \
# utc_timestamp
# 2014-01-01 00:00:00+00:00                             0.0
# 2014-01-01 01:00:00+00:00                             0.0
# 2014-01-01 02:00:00+00:00                             0.0
# 2014-01-01 03:00:00+00:00                             0.0
# 2014-01-01 04:00:00+00:00                             0.0
#
#                            DE_radiation_diffuse_horizontal
# utc_timestamp
# 2014-01-01 00:00:00+00:00                              0.0
# 2014-01-01 01:00:00+00:00                              0.0
# 2014-01-01 02:00:00+00:00                              0.0
# 2014-01-01 03:00:00+00:00                              0.0
# 2014-01-01 04:00:00+00:00                              0.0

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26304 entries, 2014-01-01 00:00:00+00:00 to 2016-12-31 23:00:00+00:00
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   DE_windspeed_10m                 26304 non-null  float64
#  1   DE_temperature                   26304 non-null  float64
#  2   DE_radiation_direct_horizontal   26304 non-null  float64
#  3   DE_radiation_diffuse_horizontal  26304 non-null  float64
# dtypes: float64(4)
# memory usage: 1.0 MB

# %%
weather.isna().sum()
# Out:
# DE_windspeed_10m                   0
# DE_temperature                     0
# DE_radiation_direct_horizontal     0
# DE_radiation_diffuse_horizontal    0
# dtype: int64

# %%
# Since the number and nature of features from the dataset  is believed not to be comprehensible enough.
# Another dataset found on https://www.renewables.ninja/ could complete the original weather dataset since it contained information on:
# precipitation in mm/hour (PRECTOTLAND in MERRA-2) 
# temperature at 2 metres above ground in degrees C (T2M in MERRA-2)
# irradiance at ground level (_surface) in W/m^2 (SWGDN in MERRA-2)
# irradiance at top of atmosphere (_toa) in W/m^2 (SWTDN in MERRA-2)
# snowfall in mm/hour (PRECSNOLAND in MERRA-2)
# snow_mass in kg/m^2 (SNOMAS in MERRA-2)
# cloud_cover as a fraction [0,1] (CLDTOT in MERRA-2)
# air_density at ground level in kg/m^3 (RHOA in MERRA-2)
weather_2 = pd.read_csv("./data/ninja_weather_country_DE_merra-2_land_area_weighted.csv",
                        parse_dates=[0], index_col=0)
weather_2.head()
# Out:
#                      precipitation  temperature  irradiance_surface  \
# time
# 1980-01-01 00:00:00         0.1234       -1.437                 0.0
# 1980-01-01 01:00:00         0.1262       -1.579                 0.0
# 1980-01-01 02:00:00         0.1260       -1.746                 0.0
# 1980-01-01 03:00:00         0.1144       -1.941                 0.0
# 1980-01-01 04:00:00         0.1078       -2.158                 0.0
#
#                      irradiance_toa  snowfall  snow_mass  cloud_cover  \
# time
# 1980-01-01 00:00:00             0.0    0.0971    10.4410       0.6287
# 1980-01-01 01:00:00             0.0    0.1017    10.5416       0.6312
# 1980-01-01 02:00:00             0.0    0.1073    10.6478       0.6320
# 1980-01-01 03:00:00             0.0    0.1025    10.7535       0.6421
# 1980-01-01 04:00:00             0.0    0.0985    10.8555       0.6484
#
#                      air_density
# time
# 1980-01-01 00:00:00       1.2438
# 1980-01-01 01:00:00       1.2447
# 1980-01-01 02:00:00       1.2456
# 1980-01-01 03:00:00       1.2465
# 1980-01-01 04:00:00       1.2475

# %%
weather_2 = (weather_2
             .loc[(weather_2.index.year == 2014) | (weather_2.index.year == 2015) | (weather_2.index.year == 2016)]
             .tz_localize('utc'))
weather_2.head()
# Out:
#                            precipitation  temperature  irradiance_surface  \
# time
# 2014-01-01 00:00:00+00:00         0.0364       -1.146                 0.0
# 2014-01-01 01:00:00+00:00         0.0449       -1.104                 0.0
# 2014-01-01 02:00:00+00:00         0.0513       -1.059                 0.0
# 2014-01-01 03:00:00+00:00         0.0544       -0.926                 0.0
# 2014-01-01 04:00:00+00:00         0.0512       -0.746                 0.0
#
#                            irradiance_toa  snowfall  snow_mass  cloud_cover  \
# time
# 2014-01-01 00:00:00+00:00             0.0    0.0056     0.2378       0.9562
# 2014-01-01 01:00:00+00:00             0.0    0.0074     0.2428       0.9672
# 2014-01-01 02:00:00+00:00             0.0    0.0129     0.2521       0.9733
# 2014-01-01 03:00:00+00:00             0.0    0.0140     0.2642       0.9651
# 2014-01-01 04:00:00+00:00             0.0    0.0144     0.2764       0.9370
#
#                            air_density
# time
# 2014-01-01 00:00:00+00:00       1.2539
# 2014-01-01 01:00:00+00:00       1.2535
# 2014-01-01 02:00:00+00:00       1.2530
# 2014-01-01 03:00:00+00:00       1.2523
# 2014-01-01 04:00:00+00:00       1.2516

# %%
weather = pd.merge(weather, weather_2, how='inner', left_index=True, right_index=True)
weather.head()
# Out:
#                            DE_windspeed_10m  DE_temperature  \
# 2014-01-01 00:00:00+00:00          4.981596          -0.568
# 2014-01-01 01:00:00+00:00          4.932105          -0.509
# 2014-01-01 02:00:00+00:00          4.865019          -0.436
# 2014-01-01 03:00:00+00:00          4.842338          -0.257
# 2014-01-01 04:00:00+00:00          4.772505          -0.082
#
#                            DE_radiation_direct_horizontal  \
# 2014-01-01 00:00:00+00:00                             0.0
# 2014-01-01 01:00:00+00:00                             0.0
# 2014-01-01 02:00:00+00:00                             0.0
# 2014-01-01 03:00:00+00:00                             0.0
# 2014-01-01 04:00:00+00:00                             0.0
#
#                            DE_radiation_diffuse_horizontal  precipitation  \
# 2014-01-01 00:00:00+00:00                              0.0         0.0364
# 2014-01-01 01:00:00+00:00                              0.0         0.0449
# 2014-01-01 02:00:00+00:00                              0.0         0.0513
# 2014-01-01 03:00:00+00:00                              0.0         0.0544
# 2014-01-01 04:00:00+00:00                              0.0         0.0512
#
#                            temperature  irradiance_surface  irradiance_toa  \
# 2014-01-01 00:00:00+00:00       -1.146                 0.0             0.0
# 2014-01-01 01:00:00+00:00       -1.104                 0.0             0.0
# 2014-01-01 02:00:00+00:00       -1.059                 0.0             0.0
# 2014-01-01 03:00:00+00:00       -0.926                 0.0             0.0
# 2014-01-01 04:00:00+00:00       -0.746                 0.0             0.0
#
#                            snowfall  snow_mass  cloud_cover  air_density
# 2014-01-01 00:00:00+00:00    0.0056     0.2378       0.9562       1.2539
# 2014-01-01 01:00:00+00:00    0.0074     0.2428       0.9672       1.2535
# 2014-01-01 02:00:00+00:00    0.0129     0.2521       0.9733       1.2530
# 2014-01-01 03:00:00+00:00    0.0140     0.2642       0.9651       1.2523
# 2014-01-01 04:00:00+00:00    0.0144     0.2764       0.9370       1.2516

# %%
# plot and compare the two temperature features to see why they seem to differ
# plt.scatter(weather["DE_temperature"], weather["temperature"])
sns.regplot(data=weather,
            x="DE_temperature",
            y="temperature");

# %%
weather[["DE_temperature", "temperature"]].corr()
# Out:
#                 DE_temperature  temperature
# DE_temperature        1.000000     0.994107
# temperature           0.994107     1.000000

# %%
# Since there's no information on how the mean temperature for Germany was calculated for both temperature features
# And since their values are not significantly different
# We can drop any of the two features for further analysis
weather = (weather
           .drop(columns= "DE_temperature")
           .rename(columns={"DE_windspeed_10m": "windspeed_10m", 
                            "DE_radiation_direct_horizontal": "radiation_direct_horizontal",
                            "DE_radiation_diffuse_horizontal": "radiation_diffuse_horizontal"}))
weather.head()
# Out:
#                            windspeed_10m  radiation_direct_horizontal  \
# 2014-01-01 00:00:00+00:00       4.981596                          0.0
# 2014-01-01 01:00:00+00:00       4.932105                          0.0
# 2014-01-01 02:00:00+00:00       4.865019                          0.0
# 2014-01-01 03:00:00+00:00       4.842338                          0.0
# 2014-01-01 04:00:00+00:00       4.772505                          0.0
#
#                            radiation_diffuse_horizontal  precipitation  \
# 2014-01-01 00:00:00+00:00                           0.0         0.0364
# 2014-01-01 01:00:00+00:00                           0.0         0.0449
# 2014-01-01 02:00:00+00:00                           0.0         0.0513
# 2014-01-01 03:00:00+00:00                           0.0         0.0544
# 2014-01-01 04:00:00+00:00                           0.0         0.0512
#
#                            temperature  irradiance_surface  irradiance_toa  \
# 2014-01-01 00:00:00+00:00       -1.146                 0.0             0.0
# 2014-01-01 01:00:00+00:00       -1.104                 0.0             0.0
# 2014-01-01 02:00:00+00:00       -1.059                 0.0             0.0
# 2014-01-01 03:00:00+00:00       -0.926                 0.0             0.0
# 2014-01-01 04:00:00+00:00       -0.746                 0.0             0.0
#
#                            snowfall  snow_mass  cloud_cover  air_density
# 2014-01-01 00:00:00+00:00    0.0056     0.2378       0.9562       1.2539
# 2014-01-01 01:00:00+00:00    0.0074     0.2428       0.9672       1.2535
# 2014-01-01 02:00:00+00:00    0.0129     0.2521       0.9733       1.2530
# 2014-01-01 03:00:00+00:00    0.0140     0.2642       0.9651       1.2523
# 2014-01-01 04:00:00+00:00    0.0144     0.2764       0.9370       1.2516

# %%
# Exploratory Data Analysis: create plot for wind velocity over time

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(weather.index,
        weather['windspeed_10m'],
        color="b");
ax.set_title("Wind velocity 10 m above displacement height (m/s)");
ax.set_xlim((pd.to_datetime("2014-01-01"), pd.to_datetime("2017-01-01")));
ax.set_ylim((0,15));
ax.set_frame_on(False);

# save plot
# plt.savefig("figs/windspeed.png", dpi=200)

# %%
# Exploratory Data Analysis: create plot for temperature

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(weather.index,
        weather['temperature'],
        color="OrangeRed");
ax.set_title("Temperature (ºC)");
ax.set_xlim((pd.to_datetime("2014-01-01"), pd.to_datetime("2017-01-01")));
ax.set_ylim((-10,35));
ax.set_frame_on(False);

# save plot
# plt.savefig("figs/temperature.png", dpi=200)

# %%
# Exploratory Data Analysis: create plot for radiation direct horizontal

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(weather.index,
        weather['radiation_direct_horizontal'],
        color="OrangeRed");
ax.set_title("Radiation direct horizontal (W/m2)");
ax.set_xlim((pd.to_datetime("2014-01-01"), pd.to_datetime("2017-01-01")));
ax.set_ylim((0,900));
ax.set_frame_on(False);

# save plot
# plt.savefig("figs/radiation_direct_horizontal.png", dpi=200)

# %%
# Exploratory Data Analysis: create plot for radiation diffuse horizontal

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(weather.index,
        weather['radiation_diffuse_horizontal'],
        color="OrangeRed");
ax.set_title("Radiation diffuse horizontal (W/m2)");
ax.set_xlim((pd.to_datetime("2015-01-01"), pd.to_datetime("2017-01-01")));
ax.set_ylim((0,400));
ax.set_frame_on(False);

# save plot
# plt.savefig("figs/radiation_diffuse_horizontal.png", dpi=200)

# %%
# Exploratory Data Analysis: create plot for irrandiance surface

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(weather.index,
        weather['irradiance_surface'],
        color="OrangeRed");
ax.set_title("Total ground horizontal radiation (W/m2)");
ax.set_xlim((pd.to_datetime("2015-01-01"), pd.to_datetime("2017-01-01")));
ax.set_ylim((0,1000));
ax.set_frame_on(False);

# save plot
# plt.savefig("figs/irradiance_surface.png", dpi=200)

# %%
# Exploratory Data Analysis: create plot for irradiance top-of-the-atmosphere

fig, ax = plt.subplots(figsize=(8,5))

ax.plot(weather.index,
        weather['irradiance_toa'],
        color="OrangeRed");
ax.set_title("Total top-of-the-atmosphere horizontal radiation (W/m2)");
ax.set_xlim((pd.to_datetime("2015-01-01"), pd.to_datetime("2017-01-01")));
ax.set_ylim((0,1250));
ax.set_frame_on(False);

# save plot
# plt.savefig("figs/irradiance_toa.png", dpi=200)

# %%
# merge production and weather DataFrames
combined = pd.merge(production, weather, how='inner', left_index=True, right_index=True)
combined
# Out:
#                            solar_capacity  solar_generation_actual  \
# 2014-01-01 00:00:00+00:00           36012                      0.0
# 2014-01-01 01:00:00+00:00           36012                      0.0
# 2014-01-01 02:00:00+00:00           36012                      0.0
# 2014-01-01 03:00:00+00:00           36012                      0.0
# 2014-01-01 04:00:00+00:00           36012                      0.0
# ...                                   ...                      ...
# 2016-12-31 19:00:00+00:00           40634                      0.0
# 2016-12-31 20:00:00+00:00           40634                      0.0
# 2016-12-31 21:00:00+00:00           40634                      0.0
# 2016-12-31 22:00:00+00:00           40634                      0.0
# 2016-12-31 23:00:00+00:00           40636                      0.0
#
#                            wind_capacity  wind_generation_actual  \
# 2014-01-01 00:00:00+00:00          32425                  8086.0
# 2014-01-01 01:00:00+00:00          32425                  8803.0
# 2014-01-01 02:00:00+00:00          32425                  8970.0
# 2014-01-01 03:00:00+00:00          32425                  8510.0
# 2014-01-01 04:00:00+00:00          32425                  8360.0
# ...                                  ...                     ...
# 2016-12-31 19:00:00+00:00          49021                 15303.0
# 2016-12-31 20:00:00+00:00          49021                 15354.0
# 2016-12-31 21:00:00+00:00          49021                 14848.0
# 2016-12-31 22:00:00+00:00          49021                 15056.0
# 2016-12-31 23:00:00+00:00          49025                 15422.0
#
#                            windspeed_10m  radiation_direct_horizontal  \
# 2014-01-01 00:00:00+00:00       4.981596                          0.0
# 2014-01-01 01:00:00+00:00       4.932105                          0.0
# 2014-01-01 02:00:00+00:00       4.865019                          0.0
# 2014-01-01 03:00:00+00:00       4.842338                          0.0
# 2014-01-01 04:00:00+00:00       4.772505                          0.0
# ...                                  ...                          ...
# Let's plot the generation of solar power (MWh) vs. weather data features
sns.pairplot(combined, x_vars=['temperature', 'precipitation', 'snowfall', 'cloud_cover', 'air_density'], y_vars=['solar_generation_actual'])
sns.pairplot(combined, x_vars=['windspeed_10m', 'radiation_direct_horizontal', 'radiation_diffuse_horizontal', 'irradiance_surface', 'irradiance_toa'], y_vars=['solar_generation_actual'])

# %%
# There seems to be a linear relation between the wind power generation and the wind velocities 
sns.jointplot(x='windspeed_10m', y='wind_generation_actual', data=combined, kind='reg')

# %%
# There seems to be a linear relation between the solar power generation and the direct radiation 
sns.jointplot(x='radiation_direct_horizontal', y='solar_generation_actual', data=combined, kind='reg')

# %%
# There may be a correlation between between  solar power generation and the irrandiance surface 
sns.jointplot(x='irradiance_surface', y='solar_generation_actual', data=combined, kind='reg')

# %%
combined.isna().sum()
# Out:
# solar_capacity                   0
# solar_generation_actual         22
# wind_capacity                    0
# wind_generation_actual           4
# windspeed_10m                    0
# radiation_direct_horizontal      0
# radiation_diffuse_horizontal     0
# precipitation                    0
# temperature                      0
# irradiance_surface               0
# irradiance_toa                   0
# snowfall                         0
# snow_mass                        0
# cloud_cover                      0
# air_density                      0
# dtype: int64

# %%
# checking where the missing values for solar_generation_actual are:
combined.loc[combined["solar_generation_actual"].isna()]
# The missing values for the generation of solar power happen to span over 22 hours in the night from 23 to 24 september of 2014
# Therefore we can assume that the values are 0 until
# Out:
#                            solar_capacity  solar_generation_actual  \
# 2014-03-29 23:00:00+00:00           36405                      NaN
# 2014-03-30 00:00:00+00:00           36405                      NaN
# 2014-03-30 02:00:00+00:00           36405                      NaN
# 2014-03-30 03:00:00+00:00           36405                      NaN
# 2014-03-30 04:00:00+00:00           36405                      NaN
# 2014-03-30 05:00:00+00:00           36405                      NaN
# 2014-03-30 06:00:00+00:00           36405                      NaN
# 2014-03-30 07:00:00+00:00           36405                      NaN
# 2014-03-30 08:00:00+00:00           36405                      NaN
# 2014-03-30 09:00:00+00:00           36405                      NaN
# 2014-03-30 10:00:00+00:00           36405                      NaN
# 2014-03-30 11:00:00+00:00           36405                      NaN
# 2014-03-30 12:00:00+00:00           36405                      NaN
# 2014-03-30 13:00:00+00:00           36405                      NaN
# 2014-03-30 14:00:00+00:00           36405                      NaN
# 2014-03-30 15:00:00+00:00           36405                      NaN
# 2014-03-30 16:00:00+00:00           36405                      NaN
# 2014-03-30 17:00:00+00:00           36405                      NaN
# 2014-03-30 18:00:00+00:00           36405                      NaN
# 2014-03-30 19:00:00+00:00           36405                      NaN
# 2014-03-30 20:00:00+00:00           36405                      NaN
# 2014-03-30 21:00:00+00:00           36405                      NaN
#
#                            wind_capacity  wind_generation_actual  \
# 2014-03-29 23:00:00+00:00          33293                  3720.0
# 2014-03-30 00:00:00+00:00          33293                  2916.0
# 2014-03-30 02:00:00+00:00          33293                  1698.0
# 2014-03-30 03:00:00+00:00          33293                  1412.0
# 2014-03-30 04:00:00+00:00          33293                  1279.0
# 2014-03-30 05:00:00+00:00          33293                  1298.0
# 2014-03-29 02:00:00+00:00                      0.000000         0.0055
# 2014-03-29 03:00:00+00:00                      0.000000         0.0054
# 2014-03-29 04:00:00+00:00                      0.047255         0.0056
# ...                                                 ...            ...
# 2014-03-31 14:00:00+00:00                    159.704463         0.0000
# 2014-03-31 15:00:00+00:00                    158.867893         0.0000
# 2014-03-31 16:00:00+00:00                    139.401837         0.0000
# 2014-03-31 17:00:00+00:00                     82.034762         0.0000
# 2014-03-31 18:00:00+00:00                     14.045660         0.0000
#
#                            temperature  irradiance_surface  irradiance_toa  \
# 2014-03-29 00:00:00+00:00        3.661              0.0000          0.0000
# 2014-03-29 01:00:00+00:00        3.489              0.0000          0.0000
# 2014-03-29 02:00:00+00:00        3.322              0.0000          0.0000
# 2014-03-29 03:00:00+00:00        3.150              0.0000          0.0000
# 2014-03-29 04:00:00+00:00        2.934              0.0748          0.6603
# ...                                ...                 ...             ...
# 2014-03-31 14:00:00+00:00       16.636            388.3612        645.8707
# 2014-03-31 15:00:00+00:00       15.854            243.2062        463.3828
# 2014-03-31 16:00:00+00:00       13.918            104.0657        254.4783
# 2014-03-31 17:00:00+00:00       11.325             13.9159         49.2278
# 2014-03-31 18:00:00+00:00       10.015              0.0000          0.0000
#
#                            snowfall  snow_mass  cloud_cover  air_density
# 2014-03-29 00:00:00+00:00       0.0     0.0083       0.4854       1.2376
# 2014-03-29 01:00:00+00:00       0.0     0.0084       0.5281       1.2390
# 2014-03-29 02:00:00+00:00       0.0     0.0084       0.5576       1.2404
# 2014-03-29 03:00:00+00:00       0.0     0.0084       0.5751       1.2419
# 2014-03-29 04:00:00+00:00       0.0     0.0083       0.5971       1.2435
# ...                             ...        ...          ...          ...
# 2014-03-31 14:00:00+00:00       0.0     0.0000       0.7871       1.1834
# 2014-03-31 15:00:00+00:00       0.0     0.0000       0.7963       1.1840
# 2014-03-31 16:00:00+00:00       0.0     0.0000       0.8059       1.1858
# 2014-03-31 17:00:00+00:00       0.0     0.0000       0.8079       1.1888
# 2014-03-31 18:00:00+00:00       0.0     0.0000       0.8048       1.1928
#
# [66 rows x 15 columns]

# %%
# We could see that the values of the timestamp: 2014-03-30 01:00:00
combined.loc[combined.index == "2014-03-30 01:00:00"]
# Out:
# Empty DataFrame
# Columns: [solar_capacity, solar_generation_actual, wind_capacity, wind_generation_actual, windspeed_10m, radiation_direct_horizontal, radiation_diffuse_horizontal, precipitation, temperature, irradiance_surface, irradiance_toa, snowfall, snow_mass, cloud_cover, air_density]
# Index: []

# %%
combined.loc[combined.index == "2014-03-29 18:00:00"]
# Out:
#                            solar_capacity  solar_generation_actual  \
# 2014-03-29 18:00:00+00:00           36402                      9.0
#
#                            wind_capacity  wind_generation_actual  \
# 2014-03-29 18:00:00+00:00          33293                  4226.0
#
#                            windspeed_10m  radiation_direct_horizontal  \
# 2014-03-29 18:00:00+00:00       3.491249                          0.0
#
#                            radiation_diffuse_horizontal  precipitation  \
# 2014-03-29 18:00:00+00:00                           0.0            0.0
#
#                            temperature  irradiance_surface  irradiance_toa  \
# 2014-03-29 18:00:00+00:00        8.695                 0.0             0.0
#
#                            snowfall  snow_mass  cloud_cover  air_density
# 2014-03-29 18:00:00+00:00       0.0     0.0012       0.2969       1.2006

# %%
# Although we could determine that the generation of solar power equals O at night, most likely from 00:00 to 04:00 and 18:00 to 24:00.
# Yet, there is no way to determine (before building a prediction model) how much the solar power was generated on 29 march 2014 from 04:00 to 18:00.
# That is why the data for 29 march 2014 from 04:00 to 18:00 will not be taken into account in this dataset.

# %%
combined.loc[(combined.index >= "2014-03-29 23:00:00") & (combined.index <= "2014-03-30 04:00:00"), "solar_generation_actual"] = 0

# %%
combined.loc[(combined.index >= "2014-03-30 18:00:00") & (combined.index <= "2014-03-30 21:00:00"), "solar_generation_actual"] = 0

# %%
combined = combined.loc[~combined["solar_generation_actual"].isna()]
combined
# Out:
#                            solar_capacity  solar_generation_actual  \
# 2014-01-01 00:00:00+00:00           36012                      0.0
# 2014-01-01 01:00:00+00:00           36012                      0.0
# 2014-01-01 02:00:00+00:00           36012                      0.0
# 2014-01-01 03:00:00+00:00           36012                      0.0
# 2014-01-01 04:00:00+00:00           36012                      0.0
# ...                                   ...                      ...
# 2016-12-31 19:00:00+00:00           40634                      0.0
# 2016-12-31 20:00:00+00:00           40634                      0.0
# 2016-12-31 21:00:00+00:00           40634                      0.0
# 2016-12-31 22:00:00+00:00           40634                      0.0
# 2016-12-31 23:00:00+00:00           40636                      0.0
#
#                            wind_capacity  wind_generation_actual  \
# 2014-01-01 00:00:00+00:00          32425                  8086.0
# 2014-01-01 01:00:00+00:00          32425                  8803.0
# 2014-01-01 02:00:00+00:00          32425                  8970.0
# 2014-01-01 03:00:00+00:00          32425                  8510.0
# 2014-01-01 04:00:00+00:00          32425                  8360.0
# ...                                  ...                     ...
# 2016-12-31 19:00:00+00:00          49021                 15303.0
# 2016-12-31 20:00:00+00:00          49021                 15354.0
# 2016-12-31 21:00:00+00:00          49021                 14848.0
# 2016-12-31 22:00:00+00:00          49021                 15056.0
# 2016-12-31 23:00:00+00:00          49025                 15422.0
#
#                            windspeed_10m  radiation_direct_horizontal  \
# 2014-01-01 00:00:00+00:00       4.981596                          0.0
# 2014-01-01 01:00:00+00:00       4.932105                          0.0
# 2014-01-01 02:00:00+00:00       4.865019                          0.0
# 2014-01-01 03:00:00+00:00       4.842338                          0.0
# 2014-01-01 04:00:00+00:00       4.772505                          0.0
# ...                                  ...                          ...
# 2016-12-31 19:00:00+00:00       4.212916                          0.0
# 2016-12-31 20:00:00+00:00       4.287475                          0.0
# 2016-12-31 21:00:00+00:00       4.296530                          0.0
# 2016-12-31 22:00:00+00:00       4.419977                          0.0
# 2016-12-31 23:00:00+00:00       4.461064                          0.0
#
#                            radiation_diffuse_horizontal  precipitation  \
# 2014-01-01 00:00:00+00:00                           0.0         0.0364
# 2014-01-01 01:00:00+00:00                           0.0         0.0449
# 2014-01-01 02:00:00+00:00                           0.0         0.0513
# 2014-03-13 00:00:00+00:00       0.0     0.0086       0.0001       1.2415
# 2014-03-13 01:00:00+00:00       0.0     0.0086       0.0002       1.2437
# 2014-03-13 02:00:00+00:00       0.0     0.0086       0.0003       1.2456

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.regplot(data=df_missing_wind,
            x="windspeed_10m",
            y="wind_generation_actual",
            ax=ax);

# %%
# add a constant
df_missing_wind = df_missing_wind.assign(const=1)

# %%
import statsmodels.api as sm

# %%
y = df_missing_wind["wind_generation_actual"]
X = df_missing_wind[["const", "windspeed_10m"]]

lin_reg = sm.OLS(y, X)
results = lin_reg.fit()

# %%
results.summary()
# Out:
# /Users/jsialell/opt/anaconda3/envs/backpack_kiwi/lib/python3.8/site-packages/scipy/stats/stats.py:1534: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/jsialell/opt/anaconda3/envs/backpack_kiwi/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# /Users/jsialell/opt/anaconda3/envs/backpack_kiwi/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# /Users/jsialell/opt/anaconda3/envs/backpack_kiwi/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     wind_generation_actual   R-squared:                         nan
# Model:                                OLS   Adj. R-squared:                    nan
# Method:                     Least Squares   F-statistic:                       nan
# Date:                    Wed, 13 May 2020   Prob (F-statistic):                nan
# Time:                            00:33:20   Log-Likelihood:                    nan
# No. Observations:                      12   AIC:                               nan
# Df Residuals:                          10   BIC:                               nan
# Df Model:                               1
# Covariance Type:                nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const                nan        nan        nan        nan         nan         nan
# windspeed_10m        nan        nan        nan        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                         34.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Out:
# <bound method IndexOpsMixin.tolist of 2014-03-12 19:00:00+00:00    3.089887
# 2014-03-12 20:00:00+00:00    3.107100
# 2014-03-12 21:00:00+00:00    3.110738
# 2014-03-12 22:00:00+00:00    3.114572
# Name: windspeed_10m, dtype: float64>

# %%
lst = []
for i in range(len(X))
    
combined.loc[combined["wind_generation_actual"].isna()]["windspeed_10m"]
# Out:
# 2014-03-12 19:00:00+00:00    3.089887
# 2014-03-12 20:00:00+00:00    3.107100
# 2014-03-12 21:00:00+00:00    3.110738
# 2014-03-12 22:00:00+00:00    3.114572
# Name: windspeed_10m, dtype: float64

# %%
predicted_wind_production = results.predict(3.089887, 1)
predicted_wind_production
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-ab589fc18cf8> in <module>
# ----> 1 predicted_wind_production = results.predict(3.089887, 1)
#       2 predicted_wind_production
#
# ~/opt/anaconda3/envs/backpack_kiwi/lib/python3.8/site-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1097             exog = np.atleast_2d(exog)  # needed in count model shape[1]
#    1098
# -> 1099         predict_results = self.model.predict(self.params, exog, *args,
#    1100                                              **kwargs)
#    1101
#
# ~/opt/anaconda3/envs/backpack_kiwi/lib/python3.8/site-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
#     378             exog = self.exog
#     379
# --> 380         return np.dot(exog, params)
#     381
#     382     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (1,1) and (2,) not aligned: 1 (dim 1) != 2 (dim 0)
